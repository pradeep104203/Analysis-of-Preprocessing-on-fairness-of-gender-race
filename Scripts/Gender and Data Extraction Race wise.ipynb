# %%
import os
import csv
import xlrd
import shutil

# %%
import pandas as pd
csv_data = pd.read_csv(r'/users/pradeep/Downloads/fairface_label_val.csv')
csv_data.head()
# Out:
#    val/1.jpg    3-9    Male       East Asian  False
# 0  val/2.jpg  50-59  Female       East Asian   True
# 1  val/3.jpg  30-39    Male            White   True
# 2  val/4.jpg  20-29  Female  Latino_Hispanic   True
# 3  val/5.jpg  20-29    Male  Southeast Asian  False
# 4  val/6.jpg  30-39    Male  Latino_Hispanic  False

# %%
csv_data.describe()
csv_data['East Asian'].unique()
# Out:
# array(['East Asian', 'White', 'Latino_Hispanic', 'Southeast Asian',
#        'Black', 'Indian', 'Middle Eastern'], dtype=object)

# %%
csv_data = r'/users/pradeep/Downloads/fairface_label_val.csv'
with open(csv_data) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in (spamreader):
        every_row = row[0].split(',')
        print(every_row)
# Out:
# ['val/1.jpg', '3-9', 'Male', 'East']
# ['val/2.jpg', '50-59', 'Female', 'East']
# ['val/3.jpg', '30-39', 'Male', 'White', 'True']
# ['val/4.jpg', '20-29', 'Female', 'Latino_Hispanic', 'True']
# ['val/5.jpg', '20-29', 'Male', 'Southeast']
# ['val/6.jpg', '30-39', 'Male', 'Latino_Hispanic', 'False']
# ['val/7.jpg', '20-29', 'Male', 'Black', 'True']
# ['val/8.jpg', '3-9', 'Male', 'East']
# ['val/9.jpg', '20-29', 'Male', 'Southeast']
# ['val/10.jpg', '3-9', 'Male', 'Southeast']
# ['val/11.jpg', 'more']
# ['val/12.jpg', '50-59', 'Female', 'East']
# ['val/13.jpg', '40-49', 'Female', 'Indian', 'True']
# ['val/14.jpg', '20-29', 'Male', 'Indian', 'True']
# ['val/15.jpg', '30-39', 'Female', 'Latino_Hispanic', 'False']
# ['val/16.jpg', '50-59', 'Male', 'Middle']
# ['val/17.jpg', '30-39', 'Male', 'East']
# ['val/18.jpg', '20-29', 'Female', 'White', 'False']
# ['val/19.jpg', '40-49', 'Male', 'White', 'False']
# ['val/20.jpg', '40-49', 'Female', 'Middle']
# ['val/21.jpg', '20-29', 'Male', 'East']
# ...

# %%
csv_data = r'/users/pradeep/Downloads/fairface_label_val.csv'

save_data = r'/users/pradeep/Downloads/fairface-img-margin025-trainval/val'

# %%
with open(csv_data) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in (spamreader):
        every_row = row[0].split(',')
        #print(every_row)
        if len(every_row)>=3:
            if every_row[2]=='Male':
                shutil.copy2(os.path.join('/users/pradeep/Downloads/fairface-img-margin025-trainval',every_row[0]),save_data+'/'+'Male')
            elif every_row[2]=='Female':
                shutil.copy2(os.path.join('/users/pradeep/Downloads/fairface-img-margin025-trainval',every_row[0]),save_data+'/'+'Female')

# %%
import os
with open(csv_data) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in (spamreader):
        every_row = row[0].split(',')
        #print(every_row)
        #csv_data['East Asian'].unique()
        if len(every_row)>=3 :
            race = every_row[3]
            if every_row[2]=='Male':
                shutil.copy2(os.path.join('/users/pradeep/Downloads/fairface-img-margin025-trainval',every_row[0]),save_data+'/'+race+'/'+'Male')
            elif every_row[2]=='Female':
                shutil.copy2(os.path.join('/users/pradeep/Downloads/fairface-img-margin025-trainval',every_row[0]),save_data+'/'+race+'/'+'Female')

# %%
csv_data = r'/users/pradeep/Downloads/fairface_label_train.csv'
save_data = r'/users/pradeep/Downloads/fairface-img-margin025-trainval/train'

# %%
with open(csv_data) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in (spamreader):
        every_row = row[0].split(',')
        #print(every_row)
        #csv_data['East Asian'].unique()
        if len(every_row)>=3 :
            race = every_row[3]
            if every_row[2]=='Male':
                shutil.copy2(os.path.join('/users/pradeep/Downloads/fairface-img-margin025-trainval',every_row[0]),save_data+'/'+race+'/'+'Male')
            elif every_row[2]=='Female':
                shutil.copy2(os.path.join('/users/pradeep/Downloads/fairface-img-margin025-trainval',every_row[0]),save_data+'/'+race+'/'+'Female')
